# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanaalkhammash/final_project_Titanic1/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
PYTON_PACKAGES = """pandas
numpy
sklearn.preprocessing
matplotlib.pyplot
seaborn"""
with open("requirements.txt", "w") as f:
    f.write(PYTON_PACKAGES)
print("done")
# Out:
# done
